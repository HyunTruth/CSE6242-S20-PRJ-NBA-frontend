# %%
import pandas as pd
import numpy as np

# %%
pbp_df = pd.concat([
    pd.read_csv('data/archive/2017_pbp.csv'),
    pd.read_csv('data/archive/2018_pbp.csv'),
    pd.read_csv('data/archive/2019_pbp.csv')])

# %%
pbp_df
# Out:
#              cl                                                 de      epid  \
# 0         12:00                                       Start Period       NaN
# 1         11:56  Jump Ball Horford vs Love (Irving gains posses...  202681.0
# 2         11:44  [BOS 2-0] Irving Driving Floating Jump Shot: M...  201143.0
# 3         11:27                      [CLE] Rose Layup Shot: Missed       NaN
# 4         11:23                [BOS] Horford Rebound (Off:0 Def:1)       NaN
# ...         ...                                                ...       ...
# 469205  00:18.9    [CHA 109-98] Bridges Free Throw 2 of 2 (16 PTS)       NaN
# 469206  00:10.3                     [MIA] Crowder 3pt Shot: Missed       NaN
# 469207  00:06.0                 [CHA] Martin Rebound (Off:1 Def:6)       NaN
# 469208  00:00.0                                         End Period       NaN
# 469209  00:00.0                                           Game End       NaN
#
#         etype  evt   game_id  hs  locX  locY  mtype       oftid      opid  \
# 0          12    2  21700001   0     0   -80      0           0       NaN
# 1          10    4  21700001   0     0   -80      0  1610612738  201567.0
# 2           1    7  21700001   0    -1   100    101  1610612738       NaN
# 3           2    9  21700001   0   -18     4      5  1610612739  201143.0
# 4           4   11  21700001   0   -18     4      0  1610612739       NaN
# ...       ...  ...       ...  ..   ...   ...    ...         ...       ...
# 469205      3  612  21900970  98     0   -80     12  1610612766       NaN
# 469206      2  613  21900970  98  -204   182      1  1610612748       NaN
# 469207      4  614  21900970  98  -204   182      0  1610612748       NaN
# 469208     13  616  21900970  98     0   -80      0  1610612766       NaN
# 469209      0  617  21900970  98     0   -80      0           0       NaN
#
#         opt1  opt2        ord      pid         tid   vs
# 0          0     0     2000.0        0           0    0
# 1          0     0     6000.0   201143  1610612738    0
# 2          2     0     7000.0   202681  1610612738    2
# 3          2     0     9000.0   201565  1610612739    2
# 4          0     0    11000.0   201143  1610612738    2
# ...      ...   ...        ...      ...         ...  ...
# 469205     1     0  6120000.0  1628970  1610612766  109
# 469206     3     0  6130000.0   203109  1610612748  109
# 469207     0     0  6140000.0  1628997  1610612766  109
# 469208     0     0  6150000.0        0           0  109
# 469209     0     0  6160000.0        0           0  109
#
# [1626703 rows x 18 columns]

# %%
event_types = {
    1: 'made shot',
    2: 'missed shot',
    3: 'free throw',
    4: 'rebound',
    5: 'turnover',
    6: 'personal foul',
    8: 'substitution',
    9: 'timeout',
    10: 'jump ball',
    12: 'start period',
    13: 'end period',
    18: 'instant replay',
    20: 'stoppage'
}

# %% [markdown]
# - `hs`: Home score
# - `vs`: Away score
# - `pid`: Player in possession
# - `locX`, `locY`: location of the event
# - `opid`: opponent player ID (So, for turnover it would be the defender with steal)
# - `oftid`: Offensive team id
# - `epid`: Related player ID. (For jumpball, person who picked it up. For goals, assist. for substitution, player replacing pid)

# %%
pbp_df.head()
# Out:
#       cl                                                 de      epid  etype  \
# 0  12:00                                       Start Period       NaN     12
# 1  11:56  Jump Ball Horford vs Love (Irving gains posses...  202681.0     10
# 2  11:44  [BOS 2-0] Irving Driving Floating Jump Shot: M...  201143.0      1
# 3  11:27                      [CLE] Rose Layup Shot: Missed       NaN      2
# 4  11:23                [BOS] Horford Rebound (Off:0 Def:1)       NaN      4
#
#    evt   game_id  hs  locX  locY  mtype       oftid      opid  opt1  opt2  \
# 0    2  21700001   0     0   -80      0           0       NaN     0     0
# 1    4  21700001   0     0   -80      0  1610612738  201567.0     0     0
# 2    7  21700001   0    -1   100    101  1610612738       NaN     2     0
# 3    9  21700001   0   -18     4      5  1610612739  201143.0     2     0
# 4   11  21700001   0   -18     4      0  1610612739       NaN     0     0
#
#        ord     pid         tid  vs
# 0   2000.0       0           0   0
# 1   6000.0  201143  1610612738   0
# 2   7000.0  202681  1610612738   2
# 3   9000.0  201565  1610612739   2
# 4  11000.0  201143  1610612738   2

# %%
pbp_df[~pbp_df['epid'].isnull()].drop_duplicates(['etype'])
# Out:
#        cl                                                 de      epid  etype  \
# 1   11:56  Jump Ball Horford vs Love (Irving gains posses...  202681.0     10
# 2   11:44  [BOS 2-0] Irving Driving Floating Jump Shot: M...  201143.0      1
# 40  07:22       [CLE] Love Substitution replaced by Thompson  202684.0      8
#
#     evt   game_id  hs  locX  locY  mtype       oftid      opid  opt1  opt2  \
# 1     4  21700001   0     0   -80      0  1610612738  201567.0     0     0
# 2     7  21700001   0    -1   100    101  1610612738       NaN     2     0
# 40   60  21700001   9     0   -80      0  1610612738       NaN     0     0
#
#         ord     pid         tid  vs
# 1    6000.0  201143  1610612738   0
# 2    7000.0  202681  1610612738   2
# 40  59000.0  201567  1610612739  10

# %%
pairings = pbp_df.drop_duplicates(['etype', 'mtype']).sort_values(['etype', 'mtype'])

# %%
pairings['de'].values
# Out:
# array(['Game End',
#        '[BOS 4-0] Horford Jump Shot: Made (2 PTS) Assist: Irving (1 AST)',
#        '[GSW 22-9] Thompson 3pt Shot: Made (11 PTS) Assist: Durant (3 AST)',
#        '[BOS 21-29] Horford Hook Shot: Made (4 PTS)',
#        '[BOS 12-9] Brown Layup Shot: Made (4 PTS)',
#        '[CLE 13-14] Rose Driving Layup Shot: Made (4 PTS)',
#        '[HOU 103-109] Capela Dunk Shot: Made (8 PTS)',
#        '[HOU 26-29] Gordon Driving Dunk Shot: Made (7 PTS)',
#        '[CLE 7-4] Rose Running Layup Shot: Made (2 PTS) Assist: James (2 AST)',
#        '[CLE 17-17] Thompson Alley Oop Layup shot: Made (2 PTS) Assist: Smith (1 AST)',
#        '[CLE 48-30] Crowder Reverse Layup Shot: Made (9 PTS) Assist: James (6 AST)',
#        '[CLE 57-42] Wade Turnaround Jump Shot: Made (7 PTS)',
#        '[BOS 10-9] Brown Running Dunk Shot: Made (2 PTS) Assist: Tatum (1 AST)',
#        '[DEN 24-16] Barton Reverse Dunk Shot: Made (7 PTS) Assist: Jokic (3 AST)',
#        '[BOS 42-54] Tatum Alley Oop Dunk Shot: Made (4 PTS) Assist: Irving (6 AST)',
#        '[ORL 2-4] Fournier Driving Hook Shot: Made (2 PTS) Assist: Payton (1 AST)',
#        '[GSW 111-105] Curry Turnaround Hook Shot: Made (15 PTS)',
#        '[BOS 6-7] Hayward Fadeaway Jump Shot: Made (2 PTS) Assist: Horford (2 AST)',
#        '[ORL 90-78] Augustin Jump Bank Shot: Made (7 PTS)',
#        '[LAC 78-59] Griffin Hook Bank Shot: Made (27 PTS) Assist: Williams (2 AST)',
#        '[NOP 24-19] Cousins Finger Roll Layup Shot: Made (9 PTS)',
#        '[CLE 41-28] Love Putback Layup Shot: Made (4 PTS)',
#        '[HOU 38-47] Mbah a Moute Driving Reverse Layup Shot: Made (2 PTS) Assist: Ariza (1 AST)',
#        '[MIA 84-97] Richardson Running Reverse Layup Shot: Made (10 PTS) Assist: Johnson (4 AST)',
#        '[HOU 86-99] Gordon Driving Finger Roll Layup Shot: Made (15 PTS)',
#        '[IND 55-48] Oladipo Running Finger Roll Layup Shot: Made (17 PTS)',
#        '[CLE 74-71] Smith Floating Jump shot: Made (10 PTS)',
#        '[BOS 14-11] Irving Pullup Jump shot: Made (6 PTS)',
#        '[BOS 8-9] Irving Step Back Jump shot: Made (4 PTS)',
#        '[CLE 5-4] Wade Turnaround Fadeaway shot: Made (2 PTS) Assist: James (1 AST)',
#        '[DET 93-81] Drummond Putback Dunk Shot: Made (6 PTS)',
#        '[CHI 31-55] Felder Driving Bank Hook Shot: Made (2 PTS) Assist: Lopez (2 AST)',
#        '[TOR 113-94] Valanciunas Turnaround Bank Hook Shot: Made (19 PTS)',
#        '[BKN 32-35] Mozgov Tip Layup Shot: Made (2 PTS)',
#        '[BOS 46-61] Brown Cutting Layup Shot: Made (14 PTS) Assist: Horford (3 AST)',
#        '[CLE 32-21] James Cutting Finger Roll Layup Shot: Made (6 PTS) Assist: Rose (1 AST)',
#        '[MEM 69-56] Martin Running Alley Oop Layup Shot: Made (4 PTS) Assist: Ennis III (2 AST)',
#        '[BOS 2-0] Irving Driving Floating Jump Shot: Made (2 PTS) Assist: Horford (1 AST)',
#        '[GSW 90-77] Durant Driving Floating Bank Jump Shot: Made (15 PTS) Assist: Green (11 AST)',
#        '[WAS 6-5] Porter Jr. Running Pull-Up Jump Shot: Made (6 PTS)',
#        '[MEM 65-56] Brooks Step Back Bank Jump Shot: Made (2 PTS)',
#        '[BOS 65-69] Smart Turnaround Fadeaway Bank Jump Shot: Made (6 PTS)',
#        '[PHX 5-8] Chandler Running Alley Oop Dunk Shot: Made (2 PTS) Assist: Warren (1 AST)',
#        '[MEM 29-34] Brooks Tip Dunk Shot: Made (6 PTS)',
#        '[CLE 76-73] Green Cutting Dunk Shot: Made (4 PTS) Assist: James (8 AST)',
#        '[DAL 9-8] Noel Driving Reverse Dunk Shot: Made (2 PTS) Assist: Barnes (1 AST)',
#        '[BOS 13-10] Brown Running Reverse Dunk Shot: Made (5 PTS)',
#        '[BOS] Hayward 3pt Shot: Missed',
#        '[HOU] Harden Running Jump Shot: Missed',
#        '[HOU] Capela Hook Shot: Missed', '[CLE] Rose Layup Shot: Missed',
#        '[BOS] Irving Driving Layup Shot: Missed',
#        '[DET] Harris Dunk Shot: Missed',
#        '[BOS] Brown Driving Dunk Shot: Missed',
#        '[BOS] Smart Running Layup Shot: Missed',
#        '[CLE] Thompson Alley Oop Layup shot: Missed',
#        '[BOS] Brown Reverse Layup Shot: Missed',
#        '[CLE] Crowder Turnaround Jump Shot: Missed',
#        '[LAL] Brewer Running Dunk Shot: Missed',
#        '[ATL] Plumlee Reverse Dunk Shot: Missed',
#        '[DET] Drummond Alley Oop Dunk Shot: Missed',
#        '[BOS] Horford Driving Hook Shot: Missed',
#        '[PHI] Simmons Turnaround Hook Shot: Missed',
#        '[CLE] Wade Fadeaway Jump Shot: Missed',
#        '[CHA] Williams Jump Bank Shot: Missed',
#        '[LAL] Lopez Hook Bank Shot: Missed',
#        '[MIA] Olynyk Finger Roll Layup Shot: Missed',
#        '[BOS] Brown Putback Layup Shot: Missed',
#        '[GSW] Curry Driving Reverse Layup Shot: Missed',
#        '[NOP] Allen Running Reverse Layup Shot: Missed',
#        '[BKN] Lin Driving Finger Roll Layup Shot: Missed',
#        '[MEM] Evans Running Finger Roll Layup Shot: Missed',
#        '[DET] Johnson Floating Jump shot: Missed',
#        '[BOS] Smart Pullup Jump shot: Missed',
#        '[BOS] Irving Step Back Jump shot: Missed',
#        '[CLE] James Turnaround Fadeaway shot: Missed',
#        '[NYK] Porzingis Putback Dunk Shot: Missed',
#        '[WAS] Mahinmi Driving Bank Hook Shot: Missed',
#        '[POR] Connaughton Turnaround Bank Hook Shot: Missed',
#        '[BOS] Tatum Tip Layup Shot: Missed',
#        '[BOS] Tatum Cutting Layup Shot: Missed',
#        '[SAS] Mills Cutting Finger Roll Layup Shot: Missed',
#        '[PHX] James Running Alley Oop Layup Shot: Missed',
#        '[CLE] Wade Driving Floating Jump Shot: Missed',
#        '[CLE] Green Driving Floating Bank Jump Shot: Missed',
#        '[ORL] Gordon 3pt Shot: Missed',
#        '[HOU] Harden Step Back Bank Jump Shot: Missed',
#        '[DAL] Nowitzki Turnaround Fadeaway Bank Jump Shot: Missed',
#        '[LAL] Kuzma Running Alley Oop Dunk Shot: Missed',
#        '[POR] Swanigan Tip Dunk Shot: Missed',
#        '[PHX] Chriss Cutting Dunk Shot: Missed',
#        '[WAS] Mark Morris Driving Reverse Dunk Shot: Missed',
#        '[TOR] Anunoby Running Reverse Dunk Shot: Missed',
#        '[BOS 17-15] Brown Free Throw 1 of 1 (7 PTS)',
#        '[CLE 8-6] Crowder Free Throw 1 of 2 (3 PTS)',
#        '[CLE 9-6] Crowder Free Throw 2 of 2 (4 PTS)',
#        '[CHA] Walker Free Throw 1 of 3 Missed',
#        '[CHA 33-44] Walker Free Throw 2 of 3 (5 PTS)',
#        '[CHA 34-44] Walker Free Throw 3 of 3 (6 PTS)',
#        '[CLE 1-4] Love Free Throw Technical (1 PTS)',
#        '[GSW 59-47] Durant Free Throw Flagrant 1 of 2 (8 PTS)',
#        '[GSW 60-47] Durant Free Throw Flagrant 2 of 2 (9 PTS)',
#        '[BOS 12-7] Tatum Free Throw Flagrant 1 of 1 (4 PTS)',
#        '[ATL 12-12] Prince Free Throw Technical 1 of 2 (4 PTS)',
#        '[ATL 13-12] Prince Free Throw Technical 2 of 2 (5 PTS)',
#        '[TOR 75-75] VanVleet Free Throw Clear Path 1 of 2 (6 PTS)',
#        '[TOR 76-75] VanVleet Free Throw Clear Path 2 of 2 (7 PTS)',
#        '[ORL 28-31] Fournier Free Throw Flagrant 1 of 3 (6 PTS)',
#        '[HOU 52-50] Harden Free Throw Flagrant 2 of 3 (6 PTS)',
#        '[HOU 53-50] Harden Free Throw Flagrant 3 of 3 (7 PTS)',
#        '[BOS] Horford Rebound (Off:0 Def:1)', '[BOS] Team Rebound',
#        '[PHI] Covington Turnover : No Turnover (1 TO)',
#        '[CLE] Love Turnover : Bad Pass (1 TO) Steal:Irving (2 ST)',
#        '[CLE] Rose Turnover : Lost Ball (1 TO) Steal:Irving (1 ST)',
#        '[CLE] Wade Turnover : Traveling (1 TO)',
#        '[BOS] Irving Turnover : Double Dribble (2 TO)',
#        '[MIA] Waiters Turnover : Discontinue Dribble (3 TO)',
#        '[HOU] Tucker Turnover : 3 Second Violation (3 TO)',
#        '[TOR] Team Turnover : 5 Second Violation',
#        '[CHA] Team Turnover : 8 Second Violation',
#        '[BOS] Team Turnover : Shot Clock Turnover',
#        '[DET] Galloway Turnover : Inbound Turnover (1 TO)',
#        '[CHA] Lamb Turnover : Backcourt Turnover (2 TO)',
#        '[UTA] Gobert Turnover : Offensive Goaltending (1 TO)',
#        '[CHI] Felicio Turnover : Lane Violation (3 TO)',
#        '[DET] Drummond Turnover : Jump Ball Violation (2 TO)',
#        '[OKC] Patterson Turnover : Kicked Ball Violation (1 TO)',
#        '[DET] Bradley Turnover : Illegal Assist Turnover (2 TO)',
#        '[BOS] Brown Turnover : Palming Turnover (1 TO)',
#        '[GSW] Pachulia Turnover : Punched Ball Turnover (1 TO)',
#        '[HOU] Gordon Turnover : Basket from Below Turnover (1 TO)',
#        '[PHI] Bayless Turnover : Illegal Screen Turnover (1 TO)',
#        '[CLE] Green Turnover : Offensive Foul Turnover (1 TO)',
#        '[BOS] Brown Turnover : Step Out of Bounds Turnover (2 TO)',
#        '[CLE] James Turnover : Out of Bounds Lost Ball Turnover (1 TO)',
#        '[DAL] Team Turnover : Excess Timeout Turnover',
#        '[SAS] Team Turnover : Too Many Players Turnover',
#        '[BOS] Smart Turnover : Out of Bounds - Bad Pass Turnover (2 TO)',
#        '[LAC] Rivers Foul: No Foul (1 PF)',
#        '[BOS] Tatum Foul: Personal (2 PF) (M McCutchen)',
#        '[BOS] Hayward Foul: Shooting (1 PF) (2 FTA) (B Forte)',
#        '[BOS] Tatum Foul: Loose Ball (3 PF) (M McCutchen)',
#        '[CLE] Thompson Foul: Offensive (3 PF) (B Forte)',
#        '[CLE] Shumpert Foul: Inbound (4 PF) (1 FTA) (M Smith)',
#        '[ORL] Speights Foul: Away From Play (1 PF) (K Cutler)',
#        '[LAC] Griffin Foul: Clear Path (1 PF) (2 FTA) (J Orr)',
#        'Foul : Double Personal - Young (1 PF), Napier (1 PF) (G Zielinski)',
#        '[BOS] Irving Technical (1 FTA) (M Smith)',
#        '[OKC] Grant Unsportsmanlike Technical (1 FTA) (D Stafford)',
#        '[TOR] Valanciunas Hanging Technical (1 FTA) (C Kirkland)',
#        '[HOU] Tucker Foul: Flagrant Type 1 (1 PF) (2 FTA) (T Maddox)',
#        '[OKC] Anthony Foul: Flagrant Type 2 (5 PF) (2 FTA) (R Mott)',
#        'Double Technical - Howard, Moreland (J DeRosa)',
#        '[BOS] Tatum Foul: Defense 3 Second (1 PF) (1 FTA) (B Forte)',
#        'Delay Technical - LAC (1 FTA) (M Callahan)',
#        '[DET] Harris Taunting Technical (1 FTA) (L Wood)',
#        'Excess Timeout Technical - DAL (1 FTA) (M Ayotte)',
#        '[CLE] Green Foul: Offensive Charge (1 PF) (M McCutchen)',
#        '[IND] Stephenson Foul: Personal Block (1 PF) (D Collins)',
#        '[BKN] LeVert Foul: Personal Take (3 PF) (2 FTA) (D Collins)',
#        '[BKN] Lin Foul: Shooting Block (1 PF) (2 FTA) (K Cutler)',
#        'Too Many Players Technical - ATL (1 FTA) (K Fitzgerald)',
#        '[CLE] Team Violation : Delay Of Game',
#        '[HOU] Capela Violation:Defensive Goaltending (R Garretson)',
#        '[CHA] Walker Violation:Lane',
#        '[PHX] Ulis Violation:Jump Ball (K Scott)',
#        '[BOS] Baynes Violation:Kicked Ball (B Forte)',
#        '[MIL] Maker Violation:Double Lane',
#        '[CLE] Love Substitution replaced by Thompson',
#        '[CLE] Team Timeout : Regular', '[MIL] Team Timeout : Challenge',
#        'Jump Ball Horford vs Love (Irving gains possession)',
#        'Challenge Jump Ball - Challenge Lopez vs Chandler (G Hill gains possession )',
#        '[GSW] Curry Ejection:Other', 'Start Period', 'End Period',
#        'Instant Replay - Support Ruling',
#        'Instant Replay - Overturn Ruling',
#        'Instant Replay - Altercation Ruling',
#        'InstantReplay Request Stands',
#        'Instant Replay - Challenge - Support Ruling',
#        'Instant Replay - Challenge - Overturn Ruling',
#        'Instant Replay - Challenge - Ruling Stands',
#        'Stoppage: Blood Rule', 'Stoppage: Injury',
#        'Stoppage: Out-of-Bounds', 'Stoppage: Court Cleanup',
#        'Stoppage: Equipment Malfunction', 'Stoppage Other'], dtype=object)

# %%
pairings['de'] = pairings['de'].str.replace(r'\[.*?\]', '', regex=True).str.strip()
pairings['de'] = pairings['de'].str.split(' \(').apply(lambda x: x[0])
pairings['de'] = pairings['de'].str.split(' ').apply(lambda x: ' '.join(x[1:]))

# %%
pairings['de'].values
# Out:
# array(['End', 'Jump Shot: Made', '3pt Shot: Made', 'Hook Shot: Made',
#        'Layup Shot: Made', 'Driving Layup Shot: Made', 'Dunk Shot: Made',
#        'Driving Dunk Shot: Made', 'Running Layup Shot: Made',
#        'Alley Oop Layup shot: Made', 'Reverse Layup Shot: Made',
#        'Turnaround Jump Shot: Made', 'Running Dunk Shot: Made',
#        'Reverse Dunk Shot: Made', 'Alley Oop Dunk Shot: Made',
#        'Driving Hook Shot: Made', 'Turnaround Hook Shot: Made',
#        'Fadeaway Jump Shot: Made', 'Jump Bank Shot: Made',
#        'Hook Bank Shot: Made', 'Finger Roll Layup Shot: Made',
#        'Putback Layup Shot: Made',
#        'a Moute Driving Reverse Layup Shot: Made',
#        'Running Reverse Layup Shot: Made',
#        'Driving Finger Roll Layup Shot: Made',
#        'Running Finger Roll Layup Shot: Made', 'Floating Jump shot: Made',
#        'Pullup Jump shot: Made', 'Step Back Jump shot: Made',
#        'Turnaround Fadeaway shot: Made', 'Putback Dunk Shot: Made',
#        'Driving Bank Hook Shot: Made', 'Turnaround Bank Hook Shot: Made',
#        'Tip Layup Shot: Made', 'Cutting Layup Shot: Made',
#        'Cutting Finger Roll Layup Shot: Made',
#        'Running Alley Oop Layup Shot: Made',
#        'Driving Floating Jump Shot: Made',
#        'Driving Floating Bank Jump Shot: Made',
#        'Jr. Running Pull-Up Jump Shot: Made',
#        'Step Back Bank Jump Shot: Made',
#        'Turnaround Fadeaway Bank Jump Shot: Made',
#        'Running Alley Oop Dunk Shot: Made', 'Tip Dunk Shot: Made',
#        'Cutting Dunk Shot: Made', 'Driving Reverse Dunk Shot: Made',
#        'Running Reverse Dunk Shot: Made', '3pt Shot: Missed',
#        'Running Jump Shot: Missed', 'Hook Shot: Missed',
#        'Layup Shot: Missed', 'Driving Layup Shot: Missed',
#        'Dunk Shot: Missed', 'Driving Dunk Shot: Missed',
#        'Running Layup Shot: Missed', 'Alley Oop Layup shot: Missed',
#        'Reverse Layup Shot: Missed', 'Turnaround Jump Shot: Missed',
#        'Running Dunk Shot: Missed', 'Reverse Dunk Shot: Missed',
#        'Alley Oop Dunk Shot: Missed', 'Driving Hook Shot: Missed',
#        'Turnaround Hook Shot: Missed', 'Fadeaway Jump Shot: Missed',
#        'Jump Bank Shot: Missed', 'Hook Bank Shot: Missed',
#        'Finger Roll Layup Shot: Missed', 'Putback Layup Shot: Missed',
#        'Driving Reverse Layup Shot: Missed',
#        'Running Reverse Layup Shot: Missed',
#        'Driving Finger Roll Layup Shot: Missed',
#        'Running Finger Roll Layup Shot: Missed',
#        'Floating Jump shot: Missed', 'Pullup Jump shot: Missed',
#        'Step Back Jump shot: Missed', 'Turnaround Fadeaway shot: Missed',
#        'Putback Dunk Shot: Missed', 'Driving Bank Hook Shot: Missed',
#        'Turnaround Bank Hook Shot: Missed', 'Tip Layup Shot: Missed',
#        'Cutting Layup Shot: Missed',
#        'Cutting Finger Roll Layup Shot: Missed',
#        'Running Alley Oop Layup Shot: Missed',
#        'Driving Floating Jump Shot: Missed',
#        'Driving Floating Bank Jump Shot: Missed', '3pt Shot: Missed',
#        'Step Back Bank Jump Shot: Missed',
#        'Turnaround Fadeaway Bank Jump Shot: Missed',
#        'Running Alley Oop Dunk Shot: Missed', 'Tip Dunk Shot: Missed',
#        'Cutting Dunk Shot: Missed',
#        'Morris Driving Reverse Dunk Shot: Missed',
#        'Running Reverse Dunk Shot: Missed', 'Free Throw 1 of 1',
#        'Free Throw 1 of 2', 'Free Throw 2 of 2',
#        'Free Throw 1 of 3 Missed', 'Free Throw 2 of 3',
#        'Free Throw 3 of 3', 'Free Throw Technical',
#        'Free Throw Flagrant 1 of 2', 'Free Throw Flagrant 2 of 2',
#        'Free Throw Flagrant 1 of 1', 'Free Throw Technical 1 of 2',
#        'Free Throw Technical 2 of 2', 'Free Throw Clear Path 1 of 2',
#        'Free Throw Clear Path 2 of 2', 'Free Throw Flagrant 1 of 3',
#        'Free Throw Flagrant 2 of 3', 'Free Throw Flagrant 3 of 3',
#        'Rebound', 'Rebound', 'Turnover : No Turnover',
#        'Turnover : Bad Pass', 'Turnover : Lost Ball',
#        'Turnover : Traveling', 'Turnover : Double Dribble',
#        'Turnover : Discontinue Dribble', 'Turnover : 3 Second Violation',
#        'Turnover : 5 Second Violation', 'Turnover : 8 Second Violation',
#        'Turnover : Shot Clock Turnover', 'Turnover : Inbound Turnover',
#        'Turnover : Backcourt Turnover',
#        'Turnover : Offensive Goaltending', 'Turnover : Lane Violation',
#        'Turnover : Jump Ball Violation',
#        'Turnover : Kicked Ball Violation',
#        'Turnover : Illegal Assist Turnover',
#        'Turnover : Palming Turnover', 'Turnover : Punched Ball Turnover',
#        'Turnover : Basket from Below Turnover',
#        'Turnover : Illegal Screen Turnover',
#        'Turnover : Offensive Foul Turnover',
#        'Turnover : Step Out of Bounds Turnover',
#        'Turnover : Out of Bounds Lost Ball Turnover',
#        'Turnover : Excess Timeout Turnover',
#        'Turnover : Too Many Players Turnover',
#        'Turnover : Out of Bounds - Bad Pass Turnover', 'Foul: No Foul',
#        'Foul: Personal', 'Foul: Shooting', 'Foul: Loose Ball',
#        'Foul: Offensive', 'Foul: Inbound', 'Foul: Away From Play',
#        'Foul: Clear Path', ': Double Personal - Young', 'Technical',
#        'Unsportsmanlike Technical', 'Hanging Technical',
#        'Foul: Flagrant Type 1', 'Foul: Flagrant Type 2',
#        'Technical - Howard, Moreland', 'Foul: Defense 3 Second',
#        'Technical - LAC', 'Taunting Technical', 'Timeout Technical - DAL',
#        'Foul: Offensive Charge', 'Foul: Personal Block',
#        'Foul: Personal Take', 'Foul: Shooting Block',
#        'Many Players Technical - ATL', 'Violation : Delay Of Game',
#        'Violation:Defensive Goaltending', 'Violation:Lane',
#        'Violation:Jump Ball', 'Violation:Kicked Ball',
#        'Violation:Double Lane', 'Substitution replaced by Thompson',
#        'Timeout : Regular', 'Timeout : Challenge', 'Ball Horford vs Love',
#        'Jump Ball - Challenge Lopez vs Chandler', 'Ejection:Other',
#        'Period', 'Period', 'Replay - Support Ruling',
#        'Replay - Overturn Ruling', 'Replay - Altercation Ruling',
#        'Request Stands', 'Replay - Challenge - Support Ruling',
#        'Replay - Challenge - Overturn Ruling',
#        'Replay - Challenge - Ruling Stands', 'Blood Rule', 'Injury',
#        'Out-of-Bounds', 'Court Cleanup', 'Equipment Malfunction', 'Other'],
#       dtype=object)

# %%
legend = pairings.set_index(['etype', 'mtype']).to_dict()['de']

# %%
legend[(8,0)] = 'Substitution'

# %%
legend
# Out:
# {(0, 0): 'End',
#  (1, 1): 'Jump Shot: Made',
#  (1, 2): '3pt Shot: Made',
#  (1, 3): 'Hook Shot: Made',
#  (1, 5): 'Layup Shot: Made',
#  (1, 6): 'Driving Layup Shot: Made',
#  (1, 7): 'Dunk Shot: Made',
#  (1, 9): 'Driving Dunk Shot: Made',
#  (1, 41): 'Running Layup Shot: Made',
#  (1, 43): 'Alley Oop Layup shot: Made',
#  (1, 44): 'Reverse Layup Shot: Made',
#  (1, 47): 'Turnaround Jump Shot: Made',
#  (1, 50): 'Running Dunk Shot: Made',
#  (1, 51): 'Reverse Dunk Shot: Made',
#  (1, 52): 'Alley Oop Dunk Shot: Made',
#  (1, 57): 'Driving Hook Shot: Made',
#  (1, 58): 'Turnaround Hook Shot: Made',
#  (1, 63): 'Fadeaway Jump Shot: Made',
#  (1, 66): 'Jump Bank Shot: Made',
#  (1, 67): 'Hook Bank Shot: Made',
#  (1, 71): 'Finger Roll Layup Shot: Made',
#  (1, 72): 'Putback Layup Shot: Made',
#  (1, 73): 'a Moute Driving Reverse Layup Shot: Made',
#  (1, 74): 'Running Reverse Layup Shot: Made',
#  (1, 75): 'Driving Finger Roll Layup Shot: Made',
#  (1, 76): 'Running Finger Roll Layup Shot: Made',
#  (1, 78): 'Floating Jump shot: Made',
#  (1, 79): 'Pullup Jump shot: Made',
#  (1, 80): 'Step Back Jump shot: Made',
#  (1, 86): 'Turnaround Fadeaway shot: Made',
#  (1, 87): 'Putback Dunk Shot: Made',
#  (1, 93): 'Driving Bank Hook Shot: Made',
#  (1, 96): 'Turnaround Bank Hook Shot: Made',
#  (1, 97): 'Tip Layup Shot: Made',
#  (1, 98): 'Cutting Layup Shot: Made',
#  (1, 99): 'Cutting Finger Roll Layup Shot: Made',
#  (1, 100): 'Running Alley Oop Layup Shot: Made',
#  (1, 101): 'Driving Floating Jump Shot: Made',
#  (1, 102): 'Driving Floating Bank Jump Shot: Made',
#  (1, 103): 'Jr. Running Pull-Up Jump Shot: Made',
#  (1, 104): 'Step Back Bank Jump Shot: Made',
#  (1, 105): 'Turnaround Fadeaway Bank Jump Shot: Made',
#  (1, 106): 'Running Alley Oop Dunk Shot: Made',
#  (1, 107): 'Tip Dunk Shot: Made',
#  (1, 108): 'Cutting Dunk Shot: Made',
#  (1, 109): 'Driving Reverse Dunk Shot: Made',
#  (1, 110): 'Running Reverse Dunk Shot: Made',
#  (2, 1): '3pt Shot: Missed',
#  (2, 2): 'Running Jump Shot: Missed',
#  (2, 3): 'Hook Shot: Missed',
#  (2, 5): 'Layup Shot: Missed',
#  (2, 6): 'Driving Layup Shot: Missed',
#  (2, 7): 'Dunk Shot: Missed',
#  (2, 9): 'Driving Dunk Shot: Missed',
#  (2, 41): 'Running Layup Shot: Missed',
#  (2, 43): 'Alley Oop Layup shot: Missed',
#  (2, 44): 'Reverse Layup Shot: Missed',
#  (2, 47): 'Turnaround Jump Shot: Missed',
#  (2, 50): 'Running Dunk Shot: Missed',
#  (2, 51): 'Reverse Dunk Shot: Missed',
#  (2, 52): 'Alley Oop Dunk Shot: Missed',
#  (2, 57): 'Driving Hook Shot: Missed',
#  (2, 58): 'Turnaround Hook Shot: Missed',
#  (2, 63): 'Fadeaway Jump Shot: Missed',
#  (2, 66): 'Jump Bank Shot: Missed',
#  (2, 67): 'Hook Bank Shot: Missed',
#  (2, 71): 'Finger Roll Layup Shot: Missed',
#  (2, 72): 'Putback Layup Shot: Missed',
#  (2, 73): 'Driving Reverse Layup Shot: Missed',
#  (2, 74): 'Running Reverse Layup Shot: Missed',
#  (2, 75): 'Driving Finger Roll Layup Shot: Missed',
#  (2, 76): 'Running Finger Roll Layup Shot: Missed',
#  (2, 78): 'Floating Jump shot: Missed',
#  (2, 79): 'Pullup Jump shot: Missed',
#  (2, 80): 'Step Back Jump shot: Missed',
#  (2, 86): 'Turnaround Fadeaway shot: Missed',
#  (2, 87): 'Putback Dunk Shot: Missed',
#  (2, 93): 'Driving Bank Hook Shot: Missed',
#  (2, 96): 'Turnaround Bank Hook Shot: Missed',
#  (2, 97): 'Tip Layup Shot: Missed',
#  (2, 98): 'Cutting Layup Shot: Missed',
#  (2, 99): 'Cutting Finger Roll Layup Shot: Missed',
#  (2, 100): 'Running Alley Oop Layup Shot: Missed',
#  (2, 101): 'Driving Floating Jump Shot: Missed',
#  (2, 102): 'Driving Floating Bank Jump Shot: Missed',
#  (2, 103): '3pt Shot: Missed',
#  (2, 104): 'Step Back Bank Jump Shot: Missed',
#  (2, 105): 'Turnaround Fadeaway Bank Jump Shot: Missed',
#  (2, 106): 'Running Alley Oop Dunk Shot: Missed',
#  (2, 107): 'Tip Dunk Shot: Missed',
#  (2, 108): 'Cutting Dunk Shot: Missed',
#  (2, 109): 'Morris Driving Reverse Dunk Shot: Missed',
#  (2, 110): 'Running Reverse Dunk Shot: Missed',
#  (3, 10): 'Free Throw 1 of 1',
#  (3, 11): 'Free Throw 1 of 2',
#  (3, 12): 'Free Throw 2 of 2',
#  (3, 13): 'Free Throw 1 of 3 Missed',
#  (3, 14): 'Free Throw 2 of 3',
#  (3, 15): 'Free Throw 3 of 3',
#  (3, 16): 'Free Throw Technical',
#  (3, 18): 'Free Throw Flagrant 1 of 2',
#  (3, 19): 'Free Throw Flagrant 2 of 2',
#  (3, 20): 'Free Throw Flagrant 1 of 1',
#  (3, 21): 'Free Throw Technical 1 of 2',
#  (3, 22): 'Free Throw Technical 2 of 2',
#  (3, 25): 'Free Throw Clear Path 1 of 2',
#  (3, 26): 'Free Throw Clear Path 2 of 2',
#  (3, 27): 'Free Throw Flagrant 1 of 3',
#  (3, 28): 'Free Throw Flagrant 2 of 3',
#  (3, 29): 'Free Throw Flagrant 3 of 3',
#  (4, 0): 'Rebound',
#  (4, 1): 'Rebound',
#  (5, 0): 'Turnover : No Turnover',
#  (5, 1): 'Turnover : Bad Pass',
#  (5, 2): 'Turnover : Lost Ball',
#  (5, 4): 'Turnover : Traveling',
#  (5, 6): 'Turnover : Double Dribble',
#  (5, 7): 'Turnover : Discontinue Dribble',
#  (5, 8): 'Turnover : 3 Second Violation',
#  (5, 9): 'Turnover : 5 Second Violation',
#  (5, 10): 'Turnover : 8 Second Violation',
#  (5, 11): 'Turnover : Shot Clock Turnover',
#  (5, 12): 'Turnover : Inbound Turnover',
#  (5, 13): 'Turnover : Backcourt Turnover',
#  (5, 15): 'Turnover : Offensive Goaltending',
#  (5, 17): 'Turnover : Lane Violation',
#  (5, 18): 'Turnover : Jump Ball Violation',
#  (5, 19): 'Turnover : Kicked Ball Violation',
#  (5, 20): 'Turnover : Illegal Assist Turnover',
#  (5, 21): 'Turnover : Palming Turnover',
#  (5, 33): 'Turnover : Punched Ball Turnover',
#  (5, 35): 'Turnover : Basket from Below Turnover',
#  (5, 36): 'Turnover : Illegal Screen Turnover',
#  (5, 37): 'Turnover : Offensive Foul Turnover',
#  (5, 39): 'Turnover : Step Out of Bounds Turnover',
#  (5, 40): 'Turnover : Out of Bounds Lost Ball Turnover',
#  (5, 42): 'Turnover : Excess Timeout Turnover',
#  (5, 44): 'Turnover : Too Many Players Turnover',
#  (5, 45): 'Turnover : Out of Bounds - Bad Pass Turnover',
#  (6, 0): 'Foul: No Foul',
#  (6, 1): 'Foul: Personal',
#  (6, 2): 'Foul: Shooting',
#  (6, 3): 'Foul: Loose Ball',
#  (6, 4): 'Foul: Offensive',
#  (6, 5): 'Foul: Inbound',
#  (6, 6): 'Foul: Away From Play',
#  (6, 9): 'Foul: Clear Path',
#  (6, 10): ': Double Personal - Young',
#  (6, 11): 'Technical',
#  (6, 12): 'Unsportsmanlike Technical',
#  (6, 13): 'Hanging Technical',
#  (6, 14): 'Foul: Flagrant Type 1',
#  (6, 15): 'Foul: Flagrant Type 2',
#  (6, 16): 'Technical - Howard, Moreland',
#  (6, 17): 'Foul: Defense 3 Second',
#  (6, 18): 'Technical - LAC',
#  (6, 19): 'Taunting Technical',
#  (6, 25): 'Timeout Technical - DAL',
#  (6, 26): 'Foul: Offensive Charge',
#  (6, 27): 'Foul: Personal Block',
#  (6, 28): 'Foul: Personal Take',
#  (6, 29): 'Foul: Shooting Block',
#  (6, 30): 'Many Players Technical - ATL',
#  (7, 1): 'Violation : Delay Of Game',
#  (7, 2): 'Violation:Defensive Goaltending',
#  (7, 3): 'Violation:Lane',
#  (7, 4): 'Violation:Jump Ball',
#  (7, 5): 'Violation:Kicked Ball',
#  (7, 6): 'Violation:Double Lane',
#  (8, 0): 'Substitution',
#  (9, 1): 'Timeout : Regular',
#  (9, 7): 'Timeout : Challenge',
#  (10, 0): 'Ball Horford vs Love',
#  (10, 1): 'Jump Ball - Challenge Lopez vs Chandler',
#  (11, 4): 'Ejection:Other',
#  (12, 0): 'Period',
#  (13, 0): 'Period',
#  (18, 0): 'Replay - Support Ruling',
#  (18, 1): 'Replay - Overturn Ruling',
#  (18, 2): 'Replay - Altercation Ruling',
#  (18, 3): 'Request Stands',
#  (18, 4): 'Replay - Challenge - Support Ruling',
#  (18, 5): 'Replay - Challenge - Overturn Ruling',
#  (18, 6): 'Replay - Challenge - Ruling Stands',
#  (20, 1): 'Blood Rule',
#  (20, 2): 'Injury',
#  (20, 3): 'Out-of-Bounds',
#  (20, 4): 'Court Cleanup',
#  (20, 5): 'Equipment Malfunction',
#  (20, 6): 'Other'}

# %% [markdown]
# I think we can pretty much understand what is going on using this legend (Have some info cut out, but conveys good enough info for us)

# %% [markdown]
# For player ID, we have full name in FinalGameLogs.csv so we can map later.

# %%
opt1 = pbp_df.drop_duplicates(['opt1', 'etype']).sort_values('etype')

# %%
opt1
# Out:
#             cl                                                 de      epid  \
# 485    00:00.0                                           Game End       NaN
# 2        11:44  [BOS 2-0] Irving Driving Floating Jump Shot: M...  201143.0
# 84       03:21  [CLE 20-17] Smith 3pt Shot: Made (3 PTS) Assis...    2544.0
# 3        11:27                      [CLE] Rose Layup Shot: Missed       NaN
# 5        11:21                     [BOS] Hayward 3pt Shot: Missed       NaN
# 127      11:10                [CLE] Rose Free Throw 2 of 2 Missed       NaN
# 14       10:32        [CLE 1-4] Love Free Throw Technical (1 PTS)       NaN
# 4        11:23                [BOS] Horford Rebound (Off:0 Def:1)       NaN
# 10       10:51                                 [BOS] Team Rebound       NaN
# 16       10:05     [BOS] Brown Turnover : Palming Turnover (1 TO)       NaN
# 35       07:49  [CLE] Rose Turnover : Lost Ball (1 TO) Steal:I...       NaN
# 13       10:32  [BOS] Tatum Foul: Defense 3 Second (1 PF) (1 F...       NaN
# 112    00:41.6  [BOS] Smart Foul: Shooting (1 PF) (1 FTA) (B F...       NaN
# 41       07:22               [CLE] Team Violation : Delay Of Game       NaN
# 40       07:22       [CLE] Love Substitution replaced by Thompson  202684.0
# 47       06:59                       [CLE] Team Timeout : Regular       NaN
# 1        11:56  Jump Ball Horford vs Love (Irving gains posses...  202681.0
# 15819  00:43.6                         [GSW] Curry Ejection:Other       NaN
# 0        12:00                                       Start Period       NaN
# 119    00:00.0                                         End Period       NaN
# 217      02:18                   Instant Replay - Overturn Ruling       NaN
# 11       10:51                            Stoppage: Out-of-Bounds       NaN
#
#        etype  evt   game_id   hs  locX  locY  mtype       oftid      opid  \
# 485        0  675  21700001  102     0   -80      0           0       NaN
# 2          1    7  21700001    0    -1   100    101  1610612738       NaN
# 84         1  112  21700001   20   232    28      1  1610612739       NaN
# 3          2    9  21700001    0   -18     4      5  1610612739  201143.0
# 5          2   12  21700001    0  -214   138      1  1610612738       NaN
# 127        3  182  21700001   30     0   -80     12  1610612739       NaN
# 14         3   23  21700001    1     0   -80     16  1610612739       NaN
# 4          4   11  21700001    0   -18     4      0  1610612739       NaN
# 10         4   18  21700001    0    10    24      0  1610612738       NaN
# 16         5   26  21700001    3    18   173     21  1610612738       NaN
# 35         5   51  21700001    9     2   208      2  1610612739  202681.0
# 13         6   22  21700001    0     0   -80     17  1610612739       NaN
# 112        6  154  21700001   28   159    49      2  1610612739    2548.0
# 41         7   61  21700001    9     0   -80      1  1610612738       NaN
# 40         8   60  21700001    9     0   -80      0  1610612738       NaN
# 47         9   67  21700001    9     0   -80      1  1610612738       NaN
# 1         10    4  21700001    0     0   -80      0  1610612738  201567.0
# 15819     11  686  21700033  107     0   -80      4  1610612763       NaN
# 0         12    2  21700001    0     0   -80      0           0       NaN
# 119       13  164  21700001   29     0   -80      0  1610612738       NaN
# 217       18  306  21700001   48     0   -80      1  1610612738       NaN
# 11        20   19  21700001    0     0   -80      3  1610612738       NaN
#
#        opt1  opt2       ord         pid         tid  vs
# 485       0     0  655000.0           0           0  99
# 2         2     0    7000.0      202681  1610612738   2
# 84        3     0  111000.0        2747  1610612739  17
# 3         2     0    9000.0      201565  1610612739   2
# 5         3     0   12000.0      202330  1610612738   2
# 127       2     0  178000.0      201565  1610612739  21
# 14        1     0   23000.0      201567  1610612739   4
# 4         0     0   11000.0      201143  1610612738   2
# 10        1     0   18000.0           0  1610612738   2
# 16        0     0   26000.0     1627759  1610612738   4
# 35        1     0   51000.0      201565  1610612739   8
# 13        0     0   22000.0     1628369  1610612738   4
# 112       1     0  151000.0      203935  1610612738  19
# 41        0     0   61000.0           0  1610612739  10
# 40        0     0   59000.0      201567  1610612739  10
# 47        0     0   67000.0  1610612739  1610612739  10
# 1         0     0    6000.0      201143  1610612738   0
# 15819     0     0  669500.0      201939  1610612744  99
# 0         0     0    2000.0           0           0   0
# 119       0     0  160000.0           0           0  19
# 217       0     0  301000.0           0           0  32
# 11        0     0   19000.0           0           0   2

# %% [markdown]
# By looking at the above, I can infer that `opt1` is:
# - for shots, it's the point attempted by the shot
# - for fouls, it's whether it's a shooting foul(1) or not(0)
# - for rebounds, it's whether it's an offensive reb(1) or def reb(0)

# %% [markdown]
# Grabbing rebounds per shot distance

# %%
test_df = pbp_df[pbp_df['game_id'] == 21900001]

# %%
test_df[(test_df['etype'] == 2) | (test_df['etype'] == 4)].to_csv('check.csv')

# %% [markdown]
# Rebound actually has the previous shooting information (is associated already), so we just have to extract defensive rebounds.

# %%
test_df[(test_df['etype']==4) & (test_df['opt1'] == 0)]
# Out:
#           cl                                    de  epid  etype  evt  \
# 6      11:25    [NOP] Redick Rebound (Off:0 Def:1)   NaN      4   11
# 8      11:15  [TOR] VanVleet Rebound (Off:0 Def:1)   NaN      4   13
# 10     11:08    [NOP] Favors Rebound (Off:1 Def:1)   NaN      4   15
# 12     10:56     [TOR] Lowry Rebound (Off:0 Def:1)   NaN      4   17
# 16     10:51    [NOP] Favors Rebound (Off:1 Def:2)   NaN      4   22
# ..       ...                                   ...   ...    ...  ...
# 556    03:21      [NOP] Ball Rebound (Off:0 Def:5)   NaN      4  762
# 569    01:44    [TOR] Powell Rebound (Off:1 Def:7)   NaN      4  781
# 577    01:14   [TOR] Anunoby Rebound (Off:3 Def:4)   NaN      4  792
# 580  00:40.6     [TOR] Gasol Rebound (Off:1 Def:3)   NaN      4  795
# 583  00:16.8     [NOP] Melli Rebound (Off:1 Def:3)   NaN      4  799
#
#       game_id   hs  locX  locY  mtype       oftid  opid  opt1  opt2  \
# 6    21900001    0    15    29      0  1610612761   NaN     0     0
# 8    21900001    0    81    -1      0  1610612740   NaN     0     0
# 10   21900001    0   178   177      0  1610612761   NaN     0     0
# 12   21900001    0    18   119      0  1610612740   NaN     0     0
# 16   21900001    1     0   -80      0  1610612761   NaN     0     0
# ..        ...  ...   ...   ...    ...         ...   ...   ...   ...
# 556  21900001  119  -145   199      0  1610612761   NaN     0     0
# 569  21900001  124   -24   108      0  1610612740   NaN     0     0
# 577  21900001  127     0    -5      0  1610612740   NaN     0     0
# 580  21900001  130   230    -5      0  1610612740   NaN     0     0
# 583  21900001  130   -10    12      0  1610612761   NaN     0     0
#
#            ord      pid         tid   vs
# 6     110000.0   200755  1610612740    2
# 8     130000.0  1627832  1610612761    2
# 10    150000.0   202324  1610612740    2
# 12    170000.0   200768  1610612761    2
# 16    210001.0   202324  1610612740    2
# ..         ...      ...         ...  ...
# 556  7590000.0  1628366  1610612740  120
# 569  7780000.0  1626181  1610612761  122
# 577  7890000.0  1628384  1610612761  122
# 580  7920000.0   201188  1610612761  122
# 583  7960000.0  1629740  1610612740  122
#
# [83 rows x 18 columns]

# %% [markdown]
# https://rdrr.io/github/sndmrc/BasketAnalyzeR/man/PbP.BDB.html
# tracking coordinate system half court

# %%
def_revs = pbp_df[(pbp_df['etype']==4) & (pbp_df['opt1'] == 0) & (pbp_df['pid'] != 0)]

# %%
min(def_revs['locY']), max(def_revs['locY'])
# Out:
# (-80, 850)

# %%
min(def_revs['locX']), max(def_revs['locX'])
# Out:
# (-250, 250)

# %%
def_revs['distance'] = np.sqrt(def_revs['locX']**2 + def_revs['locY']**2)
# Out:
# C:\Users\Jin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pid_mapper = pd.read_csv('data/archive/FinalGameLogs.csv').drop_duplicates('idPlayer').set_index('idPlayer')['Player'].to_dict()

# %%
tid_mapper = pd.read_csv('data/archive/FinalGameLogs.csv').drop_duplicates('idTeam').set_index('idTeam')['nameTeam'].to_dict()

# %%
pid_mapper[203076]
# Out:
# 'Anthony Davis'

# %%
def_revs['player'] = def_revs['pid'].map(pid_mapper)
def_revs['team'] = def_revs['tid'].map(tid_mapper)
# Out:
# C:\Users\Jin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Jin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def_revs[['game_id', 'player', 'team', 'pid', 'tid', 'locX', 'locY', 'cl', 'distance']]
# Out:
#          game_id           player                 team      pid         tid  \
# 4       21700001       Al Horford       Boston Celtics   201143  1610612738
# 6       21700001     Derrick Rose  Cleveland Cavaliers   201565  1610612739
# 8       21700001     Jaylen Brown       Boston Celtics  1627759  1610612738
# 20      21700001     LeBron James  Cleveland Cavaliers     2544  1610612739
# 30      21700001       Kevin Love  Cleveland Cavaliers   201567  1610612739
# ...          ...              ...                  ...      ...         ...
# 469168  21900970    Kendrick Nunn           Miami Heat  1629134  1610612748
# 469177  21900970  Duncan Robinson           Miami Heat  1629130  1610612748
# 469187  21900970     Caleb Martin    Charlotte Hornets  1628997  1610612766
# 469202  21900970    Miles Bridges    Charlotte Hornets  1628970  1610612766
# 469207  21900970     Caleb Martin    Charlotte Hornets  1628997  1610612766
#
#         locX  locY       cl    distance
# 4        -18     4    11:23   18.439089
# 6       -214   138    11:18  254.636997
# 8       -131    83    10:59  155.080624
# 20       -11     6    09:31   12.529964
# 30        -7    31    08:33   31.780497
# ...      ...   ...      ...         ...
# 469168    22    18    03:06   28.425341
# 469177   242     8    01:46  242.132195
# 469187   -50    25  00:52.7   55.901699
# 469202   114   239  00:22.5  264.796148
# 469207  -204   182  00:06.0  273.386174
#
# [234237 rows x 9 columns]

# %%
def_revs[['game_id', 'player', 'team', 'pid', 'tid', 'locX', 'locY', 'cl', 'distance']].to_csv('data/archive/def_revs.csv')
